# %% [markdown]
# <a href="https://colab.research.google.com/github/edgaryoungpilo-web/colab-files/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **EJEMPLO CONEXION DE GOOGLE DRIVE A GOOGLE COLAB**

# %%
print('Hola que tal')
# Out:
# Hola que tal

# %%
print('Hola')
# Out:
# Hola
